# %%
#AutoComplete - Simply hit the “Tab” key while writing code
'''6 steps of data science'''
#1.importing the data
#2.cleaning the data
#3.split the data.training_set/test_set
#4.create a model
#5.check the output
#6.improve

import pandas as pd
df_cust = pd.read_csv('Customer_ID.csv')
#df_cust #	Customer ID	Gender	Age	Income (USD/Month)

#df_cust.shape
#df_cust.describe()
# df_cust.values    #returning  an array
# df_cust1 = pd.DataFrame(df_cust, columns=['Age','Income (USD/Month)','Gender'])
# df_cust1
gender =  df_cust.groupby('Gender')['Gender'].count()
gender 
# Gender
# Female    22609
# Male      26562
# Name: Gender, dtype: int64
# Out:
# Gender
# Female    22609
# Male      26562
# Name: Gender, dtype: int64

# %%
import pandas as pd
import numpy as np
df_cabs = pd.read_csv('Cab_Data.csv')
# df_cabs
#df_cabs # Transaction ID	Date of Travel	Company	City	KM Travelled	Price Charged	Cost of Trip
# Date of Travel is in Excel Format so I converted it to Y-M-D
#df_cabs.describe()
#df_cabs.values
df_cabs1 = pd.DataFrame(df_cabs, columns=['Company','Profit'])
company =  df_cabs.groupby('Company')['Price Charged'].sum()
company.values
pink_cab = company[0]

yellow_cab = company[1]
pink_cab < yellow_cab
print(pink_cab)
print(yellow_cab)

# s = df_cabs['Date of Travel'] 
# s_int = s.astype(int)
# days = pd.to_timedelta(np.where(s_int > 59, s_int - 1, s_int), unit='D')
# secs = pd.to_timedelta(((s - s_int) * 86400.0).round().astype(int), unit='s')

# df_cabs['Date of Travel'] = pd.to_datetime('1899/12/31') + days + secs
# Out:
# 26328251.33
# 125853887.19

# %%
Company
Pink Cab       84711
Yellow Cab    274681
Name: Company, dtype: int64
# Yellow Cab have more clients than Pink Cab
# Maybe because Yellow Cab is in Washington DC
#Population of Atlanta GA 814,885 - Pink Cab operates 
#Population of Washington DC 418,859 - Yellow Cab operates
#Users of Washington DC are more than Users of Atlanta GA,despite the fact Atlanta is with more population but less users.
#We have strong negative correlation between population compared to Atlanta and Washington and users.

# %%
import pandas as pd
df_city = pd.read_csv('City.csv')
#1Population raleted to Company Yellow Cab is operating in Washington DC.How many piple we have fro this district
#2Population raleted to Company Pink Cab is operating in Atlanta GA
#find the city with most users and which company
df_city
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
im port pandas as pd
df_transactions = pd.read_csv('Transaction_ID.csv')
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
import seaborn as sns
sns.set()
graph = sns.lineplot(data=company)
graph
# Out:
# <AxesSubplot:xlabel='Company', ylabel='Price Charged'>
